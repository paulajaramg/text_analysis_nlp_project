# %% [markdown]
# # Labor informality corpus loading
#
# This notebook loads the CSV file `corpus_labor_informality_colombia.csv` and shows an initial preview of the data.

# %%
import pandas as pd

file_path = r"C:\Users\jaram\Documents\Database_exercises\visual_studio_code\MASTER DCSB\second_semester\text_analysis_nlp\data\corpus_labor_informality_colombia_180.csv"

df = pd.read_csv(file_path)

print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
df.head()
# Out:
# Filas: 180, Columnas: 4
#                                                 text  label       register  \
# 0  In Colombia, the share of workers lacking form...      0  institutional
# 1  Social protection coverage among own-account w...      0  institutional
# 2  Labor formality indicators for the 13 main met...      0  institutional
# 3  The incidence of informal employment is dispro...      0  institutional
# 4  Disaggregated data reveal that women in domest...      0  institutional
#
#   prompt_id
# 0      A001
# 1      A002
# 2      A003
# 3      A004
# 4      A005
